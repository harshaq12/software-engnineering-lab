# %% [markdown]
# <a href="https://colab.research.google.com/github/harshaq12/software-engnineering-lab/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculating weather through waterfall model
def calculate_coefficients(x, y):
    n = len(x)
    sum_x = sum(x)
    sum_y = sum(y)
    sum_x2 = sum(xi**2 for xi in x)
    sum_x3 = sum(xi**3 for xi in x)
    sum_x4 = sum(xi**4 for xi in x)
    sum_xy = sum(xi * yi for xi, yi in zip(x, y))
    sum_x2y = sum(xi**2 * yi for xi, yi in zip(x, y))
    det = (sum_x2 * sum_x4 * n + sum_x3 * sum_x2 * sum_x - sum_x3 * sum_x3 * n - sum_x2 * sum_x2 * sum_x2 - sum_x * sum_x4 * sum_x)
    det_a = (sum_x2 * sum_x4 * sum_y + sum_x3 * sum_x2 * sum_xy - sum_x3 * sum_x3 * sum_y - sum_x2 * sum_x2 * sum_xy - sum_x * sum_x4 * sum_y)
    det_b = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    det_c = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    a = det_a / det
    b = det_b / det
    c = det_c / det
    return a, b, c
def predict(x, a, b, c):
    return a * x**2 + b * x + c
def main():
    print("Welcome to the Weather Prediction System using Quadratic Regression!")
    n = int(input("Enter the number of data points (e.g., number of days): "))
    time = []
    temperature = []
    print(f"Please enter {n} pairs of (day, temperature) data:")
    for i in range(n):
        day = float(input(f"Enter day {i+1}: "))
        temp = float(input(f"Enter temperature for day {i+1} (°C): "))
        time.append(day)
        temperature.append(temp)
    print("\nCalculating quadratic model coefficients...")
    a, b, c = calculate_coefficients(time, temperature)
    print(f"\nQuadratic model coefficients:")
    print(f"a (quadratic term): {a}")
    print(f"b (linear term): {b}")
    print(f"c (constant term): {c}")
    predictions = [predict(day, a, b, c) for day in time]
    print("\nPredictions for the given days:")
    for day, pred in zip(time, predictions):
        print(f"Day {day}: Predicted Temperature = {pred:.2f} °C")
    print("\nYou can also predict the temperature for a future day.")
    future_day = float(input("Enter a future day to predict its temperature: "))
    future_pred = predict(future_day, a, b, c)
    print(f"Predicted Temperature for Day {future_day}: {future_pred:.2f} °C")
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Weather Prediction System using Quadratic Regression!
# Enter the number of data points (e.g., number of days): 2
# Please enter 2 pairs of (day, temperature) data:
# Enter day 1: 1
# Enter temperature for day 1 (°C): 10
# Enter day 2: 2
# Enter temperature for day 2 (°C): 2
#
# Calculating quadratic model coefficients...
#
# Quadratic model coefficients:
# a (quadratic term): 2.1037037037037036
# b (linear term): 2.3407407407407406
# c (constant term): 2.3407407407407406
#
# Predictions for the given days:
# Day 1.0: Predicted Temperature = 6.79 °C
# Day 2.0: Predicted Temperature = 15.44 °C
#
# You can also predict the temperature for a future day.
# Enter a future day to predict its temperature: 3
# Predicted Temperature for Day 3.0: 28.30 °C

# %%
#quadratic model using the iterative waterfall model
def calculate_coefficients(x, y):
    n = len(x)
    sum_x = sum(x)
    sum_y = sum(y)
    sum_x2 = sum(xi**2 for xi in x)
    sum_x3 = sum(xi**3 for xi in x)
    sum_x4 = sum(xi**4 for xi in x)
    sum_xy = sum(xi * yi for xi, yi in zip(x, y))
    sum_x2y = sum(xi**2 * yi for xi, yi in zip(x, y))
    det = (sum_x2 * sum_x4 * n + sum_x3 * sum_x2 * sum_x - sum_x3 * sum_x3 * n - sum_x2 * sum_x2 * sum_x2 - sum_x * sum_x4 * sum_x)
    det_a = (sum_x2 * sum_x4 * sum_y + sum_x3 * sum_x2 * sum_xy - sum_x3 * sum_x3 * sum_y - sum_x2 * sum_x2 * sum_xy - sum_x * sum_x4 * sum_y)
    det_b = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    det_c = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    a = det_a / det
    b = det_b / det
    c = det_c / det
    return a, b, c
def predict(x, a, b, c):
    return a * x**2 + b * x + c
def main():
    n = int(input("Enter the number of data points: "))
    time = []
    temperature = []
    print(f"Enter {n} pairs of (day, temperature) data:")
    for i in range(n):
        day = float(input(f"Enter day {i+1}: "))
        temp = float(input(f"Enter temperature for day {i+1} (°C): "))
        time.append(day)
        temperature.append(temp)
    a, b, c = calculate_coefficients(time, temperature)
    print(f"\nQuadratic model coefficients:")
    print(f"a (quadratic term): {a}")
    print(f"b (linear term): {b}")
    print(f"c (constant term): {c}")
    predictions = [predict(day, a, b, c) for day in time]

    print("\nPredictions for the given days:")
    for day, pred in zip(time, predictions):
        print(f"Day {day}: Predicted Temperature = {pred:.2f} °C")


if __name__ == "__main__":
    main()
# Out:
# Enter the number of data points: 2
# Enter 2 pairs of (day, temperature) data:
# Enter day 1: 1
# Enter temperature for day 1 (°C): 10
# Enter day 2: 2
# Enter temperature for day 2 (°C): 5
#
# Quadratic model coefficients:
# a (quadratic term): 2.259259259259259
# b (linear term): 2.8518518518518516
# c (constant term): 2.8518518518518516
#
# Predictions for the given days:
# Day 1.0: Predicted Temperature = 7.96 °C
# Day 2.0: Predicted Temperature = 17.59 °C

# %%
#quadratic model using the agile series
def calculate_coefficients(x, y):
    n = len(x)
    sum_x = sum(x)
    sum_y = sum(y)
    sum_x2 = sum(xi**2 for xi in x)
    sum_x3 = sum(xi**3 for xi in x)
    sum_x4 = sum(xi**4 for xi in x)
    sum_xy = sum(xi * yi for xi, yi in zip(x, y))
    sum_x2y = sum(xi**2 * yi for xi, yi in zip(x, y))
    det = (sum_x2 * sum_x4 * n + sum_x3 * sum_x2 * sum_x - sum_x3 * sum_x3 * n - sum_x2 * sum_x2 * sum_x2 - sum_x * sum_x4 * sum_x)
    det_a = (sum_x2 * sum_x4 * sum_y + sum_x3 * sum_x2 * sum_xy - sum_x3 * sum_x3 * sum_y - sum_x2 * sum_x2 * sum_xy - sum_x * sum_x4 * sum_y)
    det_b = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    det_c = (sum_x2 * sum_x4 * sum_xy + sum_x3 * sum_x2 * sum_y - sum_x3 * sum_x3 * sum_xy - sum_x2 * sum_x2 * sum_y - sum_x * sum_x4 * sum_y)
    a = det_a / det
    b = det_b / det
    c = det_c / det
    return a, b, c
def predict(x, a, b, c):
    return a * x**2 + b * x + c
def sprint_1():
    n = int(input("Enter the number of data points: "))
    time = []
    temperature = []
    print(f"Enter {n} pairs of (day, temperature) data:")
    for i in range(n):
        day = float(input(f"Enter day {i+1}: "))
        temp = float(input(f"Enter temperature for day {i+1} (°C): "))
        time.append(day)
        temperature.append(temp)
    a, b, c = calculate_coefficients(time, temperature)
    print(f"\nQuadratic model coefficients:")
    print(f"a (quadratic term): {a}")
    print(f"b (linear term): {b}")
    print(f"c (constant term): {c}")
    predictions = [predict(day, a, b, c) for day in time]
    print("\nPredictions for the given days:")
    for day, pred in zip(time, predictions):
        print(f"Day {day}: Predicted Temperature = {pred:.2f} °C")
if __name__ == "__main__":
    sprint_1()
def sprint_2():
    n = int(input("Enter the number of data points: "))
    time = []
    temperature = []
    print(f"Enter {n} pairs of (day, temperature) data:")
    for i in range(n):
        day = float(input(f"Enter day {i+1}: "))
        temp = float(input(f"Enter temperature for day {i+1} (°C): "))
        time.append(day)
        temperature.append(temp)
    a, b, c = calculate_coefficients(time, temperature)
    print(f"\nQuadratic model coefficients:")
    print(f"a (quadratic term): {a}")
    print(f"b (linear term): {b}")
    print(f"c (constant term): {c}")
    predictions = [predict(day, a, b, c) for day in time]
    print("\nPredictions for the given days:")
    for day, pred in zip(time, predictions):
        print(f"Day {day}: Predicted Temperature = {pred:.2f} °C")
    future_day = float(input("Enter a future day to predict its temperature: "))
    future_pred = predict(future_day, a, b, c)
    print(f"\nPredicted Temperature for Day {future_day}: {future_pred:.2f} °C")
if __name__ == "__main__":
    sprint_2()
# Out:
# Enter the number of data points: 2
# Enter 2 pairs of (day, temperature) data:
# Enter day 1: 1
# Enter temperature for day 1 (°C): 10
# Enter day 2: 2
# Enter temperature for day 2 (°C): 5
#
# Quadratic model coefficients:
# a (quadratic term): 2.259259259259259
# b (linear term): 2.8518518518518516
# c (constant term): 2.8518518518518516
#
# Predictions for the given days:
# Day 1.0: Predicted Temperature = 7.96 °C
# Day 2.0: Predicted Temperature = 17.59 °C
# Enter the number of data points: 2
# Enter 2 pairs of (day, temperature) data:
# Enter day 1: 1
# Enter temperature for day 1 (°C): 10
# Enter day 2: 2
# Enter temperature for day 2 (°C): 5
#
# Quadratic model coefficients:
# a (quadratic term): 2.259259259259259
# b (linear term): 2.8518518518518516
# c (constant term): 2.8518518518518516
#
# Predictions for the given days:
# Day 1.0: Predicted Temperature = 7.96 °C
# Day 2.0: Predicted Temperature = 17.59 °C
# Enter a future day to predict its temperature: 3
#
# Predicted Temperature for Day 3.0: 31.74 °C
