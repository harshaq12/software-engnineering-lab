# %% [markdown]
# <a href="https://colab.research.google.com/github/harshaq12/software-engnineering-lab/blob/main/weather_module_lab_2_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
humidity = 65
wind_speed = 15
pressure = 1010
precipitation = 12
np.random.seed(42)
num_samples = 1000
data = np.random.uniform(0, 1, (num_samples, 4))
data[:, 0] = data[:, 0] * 100
data[:, 1] = data[:, 1] * 30
data[:, 2] = data[:, 2] * 50 + 990
data[:, 3] = data[:, 3] * 100
temperature = 25 + 0.1 * data[:, 0] - 0.05 * data[:, 1] + 0.02 * data[:, 2] - 0.01 * data[:, 3]
temperature += np.random.normal(0, 5, num_samples)
X = data
y = temperature
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
user_input = np.array([[humidity, wind_speed, pressure, precipitation]])
user_input_poly = poly.transform(user_input)
predicted_temp = model.predict(user_input_poly)
print(f"Predicted Temperature: {predicted_temp[0]:.2f}°C")
# Out:
# Predicted Temperature: 50.37°C

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
print("Please enter the following weather data:")
humidity = float(input("Enter Humidity (%): "))
wind_speed = float(input("Enter Wind Speed (km/h): "))
pressure = float(input("Enter Pressure (hPa): "))
precipitation = float(input("Enter Precipitation (mm): "))
np.random.seed(42)
num_samples = 1000
data = np.random.uniform(0, 1, (num_samples, 4))
data[:, 0] = data[:, 0] * 100
data[:, 1] = data[:, 1] * 30
data[:, 2] = data[:, 2] * 50 + 990
data[:, 3] = data[:, 3] * 100
temperature = 25 + 0.1 * data[:, 0] - 0.05 * data[:, 1] + 0.02 * data[:, 2] - 0.01 * data[:, 3]
temperature += np.random.normal(0, 5, num_samples)
X = data
y = temperature
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
user_input = np.array([[humidity, wind_speed, pressure, precipitation]])
user_input_poly = poly.transform(user_input)
predicted_temp = model.predict(user_input_poly)
print(f"Predicted Temperature: {predicted_temp[0]:.2f}°C")
# Out:
# Please enter the following weather data:
# Enter Humidity (%): 89
# Enter Wind Speed (km/h): 12
# Enter Pressure (hPa): 1200
# Enter Precipitation (mm): 20
# Predicted Temperature: 28.34°C

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
data = pd.read_csv('weather_data.csv')
np.random.seed(42)
num_samples = 1000
train_data = np.random.uniform(0, 1, (num_samples, 4))
train_data[:, 0] = train_data[:, 0] * 100
train_data[:, 1] = train_data[:, 1] * 30
train_data[:, 2] = train_data[:, 2] * 50 + 990
train_data[:, 3] = train_data[:, 3] * 100
temperature = 25 + 0.1 * train_data[:, 0] - 0.05 * train_data[:, 1] + 0.02 * train_data[:, 2] - 0.01 * train_data[:, 3]
temperature += np.random.normal(0, 5, num_samples)
X_train = train_data
y_train = temperature
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
model = LinearRegression()
model.fit(X_train_poly, y_train)
for index, row in data.iterrows():
    user_input = np.array([[row['humidity'], row['wind_speed'], row['pressure'], row['precipitation']]])
    user_input_poly = poly.transform(user_input)
    predicted_temp = model.predict(user_input_poly)
    print(f"Predicted Temperature for Row {index+1}: {predicted_temp[0]:.2f}°C")
# Out:
# Predicted Temperature for Row 1: 50.05°C
# Predicted Temperature for Row 2: 51.80°C
# Predicted Temperature for Row 3: 50.72°C
# Predicted Temperature for Row 4: 49.60°C
# Predicted Temperature for Row 5: 47.23°C
# Predicted Temperature for Row 6: 47.68°C
# Predicted Temperature for Row 7: 47.18°C
# Predicted Temperature for Row 8: 51.34°C
# Predicted Temperature for Row 9: 50.74°C
# Predicted Temperature for Row 10: 51.00°C
# Predicted Temperature for Row 11: 48.26°C
# Predicted Temperature for Row 12: 50.36°C
# Predicted Temperature for Row 13: 51.25°C
# Predicted Temperature for Row 14: 49.60°C
# Predicted Temperature for Row 15: 47.85°C
# Predicted Temperature for Row 16: 46.80°C
# Predicted Temperature for Row 17: 49.71°C
# Predicted Temperature for Row 18: 50.20°C
# Predicted Temperature for Row 19: 46.74°C
# Predicted Temperature for Row 20: 49.85°C
# Predicted Temperature for Row 21: 50.43°C
# Predicted Temperature for Row 22: 48.74°C
# Predicted Temperature for Row 23: 47.82°C
# Predicted Temperature for Row 24: 46.97°C
# Predicted Temperature for Row 25: 47.66°C
# Predicted Temperature for Row 26: 51.48°C
# Predicted Temperature for Row 27: 47.25°C
# Predicted Temperature for Row 28: 49.30°C
# Predicted Temperature for Row 29: 50.73°C
# Predicted Temperature for Row 30: 46.88°C
# Predicted Temperature for Row 31: 51.62°C
# Predicted Temperature for Row 32: 48.02°C
# Predicted Temperature for Row 33: 48.53°C
# Predicted Temperature for Row 34: 54.38°C
# Predicted Temperature for Row 35: 54.31°C
# Predicted Temperature for Row 36: 51.03°C
# Predicted Temperature for Row 37: 49.11°C
# Predicted Temperature for Row 38: 47.07°C
# Predicted Temperature for Row 39: 51.87°C
# Predicted Temperature for Row 40: 50.06°C
# Predicted Temperature for Row 41: 47.65°C
# Predicted Temperature for Row 42: 48.73°C
# Predicted Temperature for Row 43: 47.64°C
# Predicted Temperature for Row 44: 51.45°C
# Predicted Temperature for Row 45: 47.71°C
# Predicted Temperature for Row 46: 50.60°C
# Predicted Temperature for Row 47: 49.43°C
# Predicted Temperature for Row 48: 51.60°C
# Predicted Temperature for Row 49: 49.26°C
# Predicted Temperature for Row 50: 49.35°C
# Predicted Temperature for Row 51: 51.68°C
# Predicted Temperature for Row 52: 51.57°C
# Predicted Temperature for Row 53: 50.61°C
# Predicted Temperature for Row 54: 52.13°C
# Predicted Temperature for Row 55: 49.40°C
# Predicted Temperature for Row 56: 51.90°C
# Predicted Temperature for Row 57: 47.20°C
# Predicted Temperature for Row 58: 48.07°C
# Predicted Temperature for Row 59: 47.12°C
# Predicted Temperature for Row 60: 48.37°C
# Predicted Temperature for Row 61: 47.39°C
# Predicted Temperature for Row 62: 46.63°C
# Predicted Temperature for Row 63: 51.43°C
# Predicted Temperature for Row 64: 49.47°C
# Predicted Temperature for Row 65: 48.76°C
# Predicted Temperature for Row 66: 49.76°C
# Predicted Temperature for Row 67: 47.92°C
# Predicted Temperature for Row 68: 51.64°C
# Predicted Temperature for Row 69: 47.74°C
# Predicted Temperature for Row 70: 53.04°C
# Predicted Temperature for Row 71: 51.97°C
# Predicted Temperature for Row 72: 49.21°C
# Predicted Temperature for Row 73: 48.63°C
# Predicted Temperature for Row 74: 53.58°C
# Predicted Temperature for Row 75: 50.16°C
# Predicted Temperature for Row 76: 50.99°C
# Predicted Temperature for Row 77: 50.88°C
# Predicted Temperature for Row 78: 46.54°C
# Predicted Temperature for Row 79: 49.98°C
# Predicted Temperature for Row 80: 46.66°C
# Predicted Temperature for Row 81: 50.33°C
# Predicted Temperature for Row 82: 50.93°C
# Predicted Temperature for Row 83: 49.11°C
# Predicted Temperature for Row 84: 46.77°C
# Predicted Temperature for Row 85: 47.80°C
# Predicted Temperature for Row 86: 49.15°C
# Predicted Temperature for Row 87: 50.41°C
# Predicted Temperature for Row 88: 51.73°C
# Predicted Temperature for Row 89: 51.29°C
# Predicted Temperature for Row 90: 50.50°C
# Predicted Temperature for Row 91: 46.83°C
# Predicted Temperature for Row 92: 50.14°C
# Predicted Temperature for Row 93: 50.81°C
# Predicted Temperature for Row 94: 49.98°C
# Predicted Temperature for Row 95: 52.12°C
# Predicted Temperature for Row 96: 50.71°C
# Predicted Temperature for Row 97: 50.09°C
# Predicted Temperature for Row 98: 50.40°C
# Predicted Temperature for Row 99: 45.87°C
# Predicted Temperature for Row 100: 48.39°C
# Predicted Temperature for Row 101: 48.36°C
# Predicted Temperature for Row 102: 49.39°C
# Predicted Temperature for Row 103: 47.52°C
# Predicted Temperature for Row 104: 49.03°C
# Predicted Temperature for Row 105: 51.49°C
# Predicted Temperature for Row 106: 49.57°C
# Predicted Temperature for Row 107: 49.65°C
# Predicted Temperature for Row 108: 50.96°C
# Predicted Temperature for Row 109: 47.92°C
# Predicted Temperature for Row 110: 48.48°C
# Predicted Temperature for Row 111: 47.68°C
# Predicted Temperature for Row 112: 48.64°C
# Predicted Temperature for Row 113: 52.61°C
# Predicted Temperature for Row 114: 52.11°C
# Predicted Temperature for Row 115: 50.60°C
# Predicted Temperature for Row 116: 50.95°C
# Predicted Temperature for Row 117: 52.45°C
# Predicted Temperature for Row 118: 46.39°C
# Predicted Temperature for Row 119: 52.40°C
# Predicted Temperature for Row 120: 51.44°C
# Predicted Temperature for Row 121: 51.11°C
# Predicted Temperature for Row 122: 51.04°C
# Predicted Temperature for Row 123: 47.68°C
# Predicted Temperature for Row 124: 47.02°C
# Predicted Temperature for Row 125: 48.02°C
# Predicted Temperature for Row 126: 49.55°C
# Predicted Temperature for Row 127: 52.77°C
# Predicted Temperature for Row 128: 51.71°C
# Predicted Temperature for Row 129: 47.29°C
# Predicted Temperature for Row 130: 50.31°C
# Predicted Temperature for Row 131: 48.52°C
# Predicted Temperature for Row 132: 48.19°C
# Predicted Temperature for Row 133: 48.76°C
# Predicted Temperature for Row 134: 49.96°C
# Predicted Temperature for Row 135: 52.54°C
# Predicted Temperature for Row 136: 50.03°C
# Predicted Temperature for Row 137: 48.53°C
# Predicted Temperature for Row 138: 51.05°C
# Predicted Temperature for Row 139: 49.10°C
# Predicted Temperature for Row 140: 53.12°C
# Predicted Temperature for Row 141: 52.41°C
# Predicted Temperature for Row 142: 48.75°C
# Predicted Temperature for Row 143: 49.64°C
# Predicted Temperature for Row 144: 48.68°C
# Predicted Temperature for Row 145: 49.43°C
# Predicted Temperature for Row 146: 46.47°C
# Predicted Temperature for Row 147: 49.39°C
# Predicted Temperature for Row 148: 49.43°C
# Predicted Temperature for Row 149: 46.82°C
# Predicted Temperature for Row 150: 47.93°C
# Predicted Temperature for Row 151: 51.52°C
# Predicted Temperature for Row 152: 46.86°C
# Predicted Temperature for Row 153: 47.67°C
# Predicted Temperature for Row 154: 49.67°C
# Predicted Temperature for Row 155: 51.90°C
# Predicted Temperature for Row 156: 47.79°C
# Predicted Temperature for Row 157: 50.91°C
# Predicted Temperature for Row 158: 49.75°C
# Predicted Temperature for Row 159: 47.54°C
# Predicted Temperature for Row 160: 52.92°C
# Predicted Temperature for Row 161: 48.48°C
# Predicted Temperature for Row 162: 51.79°C
# Predicted Temperature for Row 163: 51.12°C
# Predicted Temperature for Row 164: 49.78°C
# Predicted Temperature for Row 165: 48.30°C
# Predicted Temperature for Row 166: 51.57°C
# Predicted Temperature for Row 167: 47.92°C
# Predicted Temperature for Row 168: 47.32°C
# Predicted Temperature for Row 169: 48.81°C
# Predicted Temperature for Row 170: 51.03°C
# Predicted Temperature for Row 171: 50.75°C
# Predicted Temperature for Row 172: 45.06°C
# Predicted Temperature for Row 173: 48.90°C
# Predicted Temperature for Row 174: 49.07°C
# Predicted Temperature for Row 175: 49.62°C
# Predicted Temperature for Row 176: 47.97°C
# Predicted Temperature for Row 177: 49.97°C
# Predicted Temperature for Row 178: 49.93°C
# Predicted Temperature for Row 179: 51.63°C
# Predicted Temperature for Row 180: 48.07°C
# Predicted Temperature for Row 181: 46.83°C
# Predicted Temperature for Row 182: 48.11°C
# Predicted Temperature for Row 183: 51.27°C
# Predicted Temperature for Row 184: 50.56°C
# Predicted Temperature for Row 185: 49.87°C
# Predicted Temperature for Row 186: 50.07°C
# Predicted Temperature for Row 187: 51.81°C
# Predicted Temperature for Row 188: 51.70°C
# Predicted Temperature for Row 189: 50.29°C
# Predicted Temperature for Row 190: 48.05°C
# Predicted Temperature for Row 191: 48.99°C
# Predicted Temperature for Row 192: 51.51°C
# Predicted Temperature for Row 193: 51.85°C
# Predicted Temperature for Row 194: 50.51°C
# Predicted Temperature for Row 195: 50.17°C
# Predicted Temperature for Row 196: 48.11°C
# Predicted Temperature for Row 197: 49.45°C
# Predicted Temperature for Row 198: 50.85°C
# Predicted Temperature for Row 199: 51.56°C
# Predicted Temperature for Row 200: 52.66°C
# Predicted Temperature for Row 201: 50.38°C
# Predicted Temperature for Row 202: 49.17°C
# Predicted Temperature for Row 203: 49.40°C
# Predicted Temperature for Row 204: 51.64°C
# Predicted Temperature for Row 205: 50.63°C
# Predicted Temperature for Row 206: 46.62°C
# Predicted Temperature for Row 207: 47.38°C
# Predicted Temperature for Row 208: 50.90°C
# Predicted Temperature for Row 209: 48.11°C
# Predicted Temperature for Row 210: 46.97°C
# Predicted Temperature for Row 211: 50.59°C
# Predicted Temperature for Row 212: 51.22°C
# Predicted Temperature for Row 213: 51.10°C
# Predicted Temperature for Row 214: 47.74°C
# Predicted Temperature for Row 215: 50.92°C
# Predicted Temperature for Row 216: 48.91°C
# Predicted Temperature for Row 217: 50.19°C
# Predicted Temperature for Row 218: 50.07°C
# Predicted Temperature for Row 219: 50.42°C
# Predicted Temperature for Row 220: 51.90°C
# Predicted Temperature for Row 221: 49.88°C
# Predicted Temperature for Row 222: 51.39°C
# Predicted Temperature for Row 223: 47.00°C
# Predicted Temperature for Row 224: 46.63°C
# Predicted Temperature for Row 225: 48.01°C
# Predicted Temperature for Row 226: 48.10°C
# Predicted Temperature for Row 227: 52.95°C
# Predicted Temperature for Row 228: 50.14°C
# Predicted Temperature for Row 229: 50.23°C
# Predicted Temperature for Row 230: 50.72°C
# Predicted Temperature for Row 231: 50.93°C
# Predicted Temperature for Row 232: 50.35°C
# Predicted Temperature for Row 233: 51.47°C
# Predicted Temperature for Row 234: 51.30°C
# Predicted Temperature for Row 235: 48.00°C
# Predicted Temperature for Row 236: 51.83°C
# Predicted Temperature for Row 237: 47.71°C
# Predicted Temperature for Row 238: 47.53°C
# Predicted Temperature for Row 239: 48.81°C
# Predicted Temperature for Row 240: 49.18°C
# Predicted Temperature for Row 241: 52.09°C
# Predicted Temperature for Row 242: 51.02°C
# Predicted Temperature for Row 243: 51.84°C
# Predicted Temperature for Row 244: 48.40°C
# Predicted Temperature for Row 245: 46.84°C
# Predicted Temperature for Row 246: 52.29°C
# Predicted Temperature for Row 247: 50.34°C
# Predicted Temperature for Row 248: 54.41°C
# Predicted Temperature for Row 249: 51.19°C
# Predicted Temperature for Row 250: 51.08°C
# Predicted Temperature for Row 251: 47.62°C
# Predicted Temperature for Row 252: 49.36°C
# Predicted Temperature for Row 253: 53.06°C
# Predicted Temperature for Row 254: 49.96°C
# Predicted Temperature for Row 255: 47.72°C
# Predicted Temperature for Row 256: 50.46°C
# Predicted Temperature for Row 257: 53.11°C
# Predicted Temperature for Row 258: 51.05°C
# Predicted Temperature for Row 259: 51.57°C
# Predicted Temperature for Row 260: 47.62°C
# Predicted Temperature for Row 261: 51.53°C
# Predicted Temperature for Row 262: 52.31°C
# Predicted Temperature for Row 263: 48.61°C
# Predicted Temperature for Row 264: 49.73°C
# Predicted Temperature for Row 265: 52.94°C
# Predicted Temperature for Row 266: 52.77°C
# Predicted Temperature for Row 267: 51.58°C
# Predicted Temperature for Row 268: 51.36°C
# Predicted Temperature for Row 269: 48.79°C
# Predicted Temperature for Row 270: 49.45°C
# Predicted Temperature for Row 271: 50.46°C
# Predicted Temperature for Row 272: 50.12°C
# Predicted Temperature for Row 273: 51.17°C
# Predicted Temperature for Row 274: 53.76°C
# Predicted Temperature for Row 275: 49.71°C
# Predicted Temperature for Row 276: 50.66°C
# Predicted Temperature for Row 277: 51.85°C
# Predicted Temperature for Row 278: 49.51°C
# Predicted Temperature for Row 279: 52.38°C
# Predicted Temperature for Row 280: 50.83°C
# Predicted Temperature for Row 281: 51.65°C
# Predicted Temperature for Row 282: 48.03°C
# Predicted Temperature for Row 283: 48.93°C
# Predicted Temperature for Row 284: 49.06°C
# Predicted Temperature for Row 285: 50.59°C
# Predicted Temperature for Row 286: 46.62°C
# Predicted Temperature for Row 287: 51.02°C
# Predicted Temperature for Row 288: 50.27°C
# Predicted Temperature for Row 289: 49.67°C
# Predicted Temperature for Row 290: 51.39°C
# Predicted Temperature for Row 291: 47.27°C
# Predicted Temperature for Row 292: 48.57°C
# Predicted Temperature for Row 293: 51.31°C
# Predicted Temperature for Row 294: 48.78°C
# Predicted Temperature for Row 295: 46.85°C
# Predicted Temperature for Row 296: 49.98°C
# Predicted Temperature for Row 297: 52.06°C
# Predicted Temperature for Row 298: 48.73°C
# Predicted Temperature for Row 299: 49.72°C
# Predicted Temperature for Row 300: 47.31°C
# Predicted Temperature for Row 301: 48.93°C
# Predicted Temperature for Row 302: 48.51°C
# Predicted Temperature for Row 303: 51.46°C
# Predicted Temperature for Row 304: 50.41°C
# Predicted Temperature for Row 305: 51.14°C
# Predicted Temperature for Row 306: 51.70°C
# Predicted Temperature for Row 307: 48.82°C
# Predicted Temperature for Row 308: 47.66°C
# Predicted Temperature for Row 309: 51.69°C
# Predicted Temperature for Row 310: 47.73°C
# Predicted Temperature for Row 311: 50.63°C
# Predicted Temperature for Row 312: 46.82°C
# Predicted Temperature for Row 313: 47.56°C
# Predicted Temperature for Row 314: 52.05°C
# Predicted Temperature for Row 315: 52.66°C
# Predicted Temperature for Row 316: 50.16°C
# Predicted Temperature for Row 317: 49.28°C
# Predicted Temperature for Row 318: 46.52°C
# Predicted Temperature for Row 319: 49.23°C
# Predicted Temperature for Row 320: 49.73°C
# Predicted Temperature for Row 321: 51.02°C
# Predicted Temperature for Row 322: 52.39°C
# Predicted Temperature for Row 323: 49.80°C
# Predicted Temperature for Row 324: 49.59°C
# Predicted Temperature for Row 325: 51.41°C
# Predicted Temperature for Row 326: 51.52°C
# Predicted Temperature for Row 327: 50.72°C
# Predicted Temperature for Row 328: 49.02°C
# Predicted Temperature for Row 329: 48.92°C
# Predicted Temperature for Row 330: 48.38°C
# Predicted Temperature for Row 331: 48.93°C
# Predicted Temperature for Row 332: 50.05°C
# Predicted Temperature for Row 333: 47.97°C
# Predicted Temperature for Row 334: 46.15°C
# Predicted Temperature for Row 335: 46.20°C
# Predicted Temperature for Row 336: 47.32°C
# Predicted Temperature for Row 337: 52.00°C
# Predicted Temperature for Row 338: 50.33°C
# Predicted Temperature for Row 339: 50.78°C
# Predicted Temperature for Row 340: 49.27°C
# Predicted Temperature for Row 341: 50.04°C
# Predicted Temperature for Row 342: 49.54°C
# Predicted Temperature for Row 343: 46.91°C
# Predicted Temperature for Row 344: 48.43°C
# Predicted Temperature for Row 345: 48.97°C
# Predicted Temperature for Row 346: 50.75°C
# Predicted Temperature for Row 347: 51.42°C
# Predicted Temperature for Row 348: 47.63°C
# Predicted Temperature for Row 349: 47.84°C
# Predicted Temperature for Row 350: 51.44°C
# Predicted Temperature for Row 351: 48.90°C
# Predicted Temperature for Row 352: 52.34°C
# Predicted Temperature for Row 353: 50.50°C
# Predicted Temperature for Row 354: 47.69°C
# Predicted Temperature for Row 355: 47.52°C
# Predicted Temperature for Row 356: 48.46°C
# Predicted Temperature for Row 357: 46.52°C
# Predicted Temperature for Row 358: 50.16°C
# Predicted Temperature for Row 359: 52.61°C
# Predicted Temperature for Row 360: 49.73°C
# Predicted Temperature for Row 361: 47.62°C
# Predicted Temperature for Row 362: 51.64°C
# Predicted Temperature for Row 363: 49.23°C
# Predicted Temperature for Row 364: 49.80°C
# Predicted Temperature for Row 365: 51.28°C
# Predicted Temperature for Row 366: 50.09°C
# Predicted Temperature for Row 367: 51.45°C
# Predicted Temperature for Row 368: 51.37°C
# Predicted Temperature for Row 369: 49.01°C
# Predicted Temperature for Row 370: 48.44°C
# Predicted Temperature for Row 371: 46.18°C
# Predicted Temperature for Row 372: 48.31°C
# Predicted Temperature for Row 373: 46.65°C
# Predicted Temperature for Row 374: 50.91°C
# Predicted Temperature for Row 375: 48.32°C
# Predicted Temperature for Row 376: 47.81°C
# Predicted Temperature for Row 377: 51.63°C
# Predicted Temperature for Row 378: 47.18°C
# Predicted Temperature for Row 379: 52.15°C
# Predicted Temperature for Row 380: 48.59°C
# Predicted Temperature for Row 381: 48.91°C
# Predicted Temperature for Row 382: 51.73°C
# Predicted Temperature for Row 383: 49.41°C
# Predicted Temperature for Row 384: 52.98°C
# Predicted Temperature for Row 385: 50.24°C
# Predicted Temperature for Row 386: 51.59°C
# Predicted Temperature for Row 387: 47.61°C
# Predicted Temperature for Row 388: 49.39°C
# Predicted Temperature for Row 389: 50.02°C
# Predicted Temperature for Row 390: 51.88°C
# Predicted Temperature for Row 391: 53.70°C
# Predicted Temperature for Row 392: 50.11°C
# Predicted Temperature for Row 393: 49.78°C
# Predicted Temperature for Row 394: 51.03°C
# Predicted Temperature for Row 395: 49.00°C
# Predicted Temperature for Row 396: 50.60°C
# Predicted Temperature for Row 397: 51.40°C
# Predicted Temperature for Row 398: 49.71°C
# Predicted Temperature for Row 399: 51.34°C
# Predicted Temperature for Row 400: 51.04°C
# Predicted Temperature for Row 401: 48.28°C
# Predicted Temperature for Row 402: 52.63°C
# Predicted Temperature for Row 403: 50.36°C
# Predicted Temperature for Row 404: 50.97°C
# Predicted Temperature for Row 405: 48.58°C
# Predicted Temperature for Row 406: 52.00°C
# Predicted Temperature for Row 407: 48.21°C
# Predicted Temperature for Row 408: 46.56°C
# Predicted Temperature for Row 409: 52.81°C
# Predicted Temperature for Row 410: 45.75°C
# Predicted Temperature for Row 411: 49.94°C
# Predicted Temperature for Row 412: 53.33°C
# Predicted Temperature for Row 413: 53.38°C
# Predicted Temperature for Row 414: 51.22°C
# Predicted Temperature for Row 415: 50.40°C
# Predicted Temperature for Row 416: 48.75°C
# Predicted Temperature for Row 417: 50.16°C
# Predicted Temperature for Row 418: 49.86°C
# Predicted Temperature for Row 419: 50.30°C
# Predicted Temperature for Row 420: 49.47°C
# Predicted Temperature for Row 421: 51.50°C
# Predicted Temperature for Row 422: 50.89°C
# Predicted Temperature for Row 423: 48.87°C
# Predicted Temperature for Row 424: 50.68°C
# Predicted Temperature for Row 425: 46.37°C
# Predicted Temperature for Row 426: 49.24°C
# Predicted Temperature for Row 427: 50.83°C
# Predicted Temperature for Row 428: 51.42°C
# Predicted Temperature for Row 429: 48.54°C
# Predicted Temperature for Row 430: 47.08°C
# Predicted Temperature for Row 431: 48.36°C
# Predicted Temperature for Row 432: 50.60°C
# Predicted Temperature for Row 433: 50.48°C
# Predicted Temperature for Row 434: 47.29°C
# Predicted Temperature for Row 435: 48.46°C
# Predicted Temperature for Row 436: 52.49°C
# Predicted Temperature for Row 437: 48.05°C
# Predicted Temperature for Row 438: 51.07°C
# Predicted Temperature for Row 439: 51.18°C
# Predicted Temperature for Row 440: 47.20°C
# Predicted Temperature for Row 441: 46.30°C
# Predicted Temperature for Row 442: 54.04°C
# Predicted Temperature for Row 443: 48.80°C
# Predicted Temperature for Row 444: 48.72°C
# Predicted Temperature for Row 445: 50.03°C
# Predicted Temperature for Row 446: 53.12°C
# Predicted Temperature for Row 447: 51.60°C
# Predicted Temperature for Row 448: 49.96°C
# Predicted Temperature for Row 449: 47.50°C
# Predicted Temperature for Row 450: 46.28°C
# Predicted Temperature for Row 451: 51.38°C
# Predicted Temperature for Row 452: 50.03°C
# Predicted Temperature for Row 453: 48.61°C
# Predicted Temperature for Row 454: 52.09°C
# Predicted Temperature for Row 455: 48.79°C
# Predicted Temperature for Row 456: 47.63°C
# Predicted Temperature for Row 457: 46.99°C
# Predicted Temperature for Row 458: 49.37°C
# Predicted Temperature for Row 459: 48.57°C
# Predicted Temperature for Row 460: 47.64°C
# Predicted Temperature for Row 461: 48.12°C
# Predicted Temperature for Row 462: 50.69°C
# Predicted Temperature for Row 463: 52.38°C
# Predicted Temperature for Row 464: 50.09°C
# Predicted Temperature for Row 465: 51.53°C
# Predicted Temperature for Row 466: 50.35°C
# Predicted Temperature for Row 467: 47.34°C
# Predicted Temperature for Row 468: 51.60°C
# Predicted Temperature for Row 469: 47.48°C
# Predicted Temperature for Row 470: 52.07°C
# Predicted Temperature for Row 471: 46.05°C
# Predicted Temperature for Row 472: 52.08°C
# Predicted Temperature for Row 473: 46.67°C
# Predicted Temperature for Row 474: 52.45°C
# Predicted Temperature for Row 475: 50.26°C
# Predicted Temperature for Row 476: 52.29°C
# Predicted Temperature for Row 477: 46.76°C
# Predicted Temperature for Row 478: 49.81°C
# Predicted Temperature for Row 479: 51.28°C
# Predicted Temperature for Row 480: 50.53°C
# Predicted Temperature for Row 481: 49.15°C
# Predicted Temperature for Row 482: 52.16°C
# Predicted Temperature for Row 483: 49.80°C
# Predicted Temperature for Row 484: 51.13°C
# Predicted Temperature for Row 485: 50.93°C
# Predicted Temperature for Row 486: 52.88°C
# Predicted Temperature for Row 487: 47.89°C
# Predicted Temperature for Row 488: 47.89°C
# Predicted Temperature for Row 489: 53.18°C
# Predicted Temperature for Row 490: 52.39°C
# Predicted Temperature for Row 491: 50.01°C
# Predicted Temperature for Row 492: 50.72°C
# Predicted Temperature for Row 493: 49.08°C
# Predicted Temperature for Row 494: 49.25°C
# Predicted Temperature for Row 495: 49.51°C
# Predicted Temperature for Row 496: 48.46°C
# Predicted Temperature for Row 497: 49.81°C
# Predicted Temperature for Row 498: 47.57°C
# Predicted Temperature for Row 499: 53.87°C
# Predicted Temperature for Row 500: 51.52°C
# Predicted Temperature for Row 501: 51.44°C
# Predicted Temperature for Row 502: 50.02°C
# Predicted Temperature for Row 503: 49.47°C
# Predicted Temperature for Row 504: 52.71°C
# Predicted Temperature for Row 505: 50.57°C
# Predicted Temperature for Row 506: 48.39°C
# Predicted Temperature for Row 507: 51.38°C
# Predicted Temperature for Row 508: 51.79°C
# Predicted Temperature for Row 509: 52.00°C
# Predicted Temperature for Row 510: 50.79°C
# Predicted Temperature for Row 511: 48.90°C
# Predicted Temperature for Row 512: 48.77°C
# Predicted Temperature for Row 513: 50.49°C
# Predicted Temperature for Row 514: 52.77°C
# Predicted Temperature for Row 515: 48.31°C
# Predicted Temperature for Row 516: 48.02°C
# Predicted Temperature for Row 517: 47.53°C
# Predicted Temperature for Row 518: 50.70°C
# Predicted Temperature for Row 519: 54.08°C
# Predicted Temperature for Row 520: 46.64°C
# Predicted Temperature for Row 521: 51.96°C
# Predicted Temperature for Row 522: 47.58°C
# Predicted Temperature for Row 523: 53.08°C
# Predicted Temperature for Row 524: 53.04°C
# Predicted Temperature for Row 525: 52.45°C
# Predicted Temperature for Row 526: 50.13°C
# Predicted Temperature for Row 527: 49.45°C
# Predicted Temperature for Row 528: 48.97°C
# Predicted Temperature for Row 529: 46.61°C
# Predicted Temperature for Row 530: 52.51°C
# Predicted Temperature for Row 531: 52.68°C
# Predicted Temperature for Row 532: 52.45°C
# Predicted Temperature for Row 533: 52.10°C
# Predicted Temperature for Row 534: 50.32°C
# Predicted Temperature for Row 535: 52.14°C
# Predicted Temperature for Row 536: 54.27°C
# Predicted Temperature for Row 537: 53.34°C
# Predicted Temperature for Row 538: 47.63°C
# Predicted Temperature for Row 539: 50.48°C
# Predicted Temperature for Row 540: 47.48°C
# Predicted Temperature for Row 541: 52.46°C
# Predicted Temperature for Row 542: 51.16°C
# Predicted Temperature for Row 543: 48.15°C
# Predicted Temperature for Row 544: 51.86°C
# Predicted Temperature for Row 545: 48.57°C
# Predicted Temperature for Row 546: 48.99°C
# Predicted Temperature for Row 547: 45.62°C
# Predicted Temperature for Row 548: 50.80°C
# Predicted Temperature for Row 549: 51.41°C
# Predicted Temperature for Row 550: 50.52°C
# Predicted Temperature for Row 551: 48.58°C
# Predicted Temperature for Row 552: 50.91°C
# Predicted Temperature for Row 553: 49.63°C
# Predicted Temperature for Row 554: 49.59°C
# Predicted Temperature for Row 555: 52.31°C
# Predicted Temperature for Row 556: 50.11°C
# Predicted Temperature for Row 557: 47.56°C
# Predicted Temperature for Row 558: 47.84°C
# Predicted Temperature for Row 559: 49.19°C
# Predicted Temperature for Row 560: 49.58°C
# Predicted Temperature for Row 561: 51.91°C
# Predicted Temperature for Row 562: 48.94°C
# Predicted Temperature for Row 563: 45.68°C
# Predicted Temperature for Row 564: 47.95°C
# Predicted Temperature for Row 565: 48.18°C
# Predicted Temperature for Row 566: 50.40°C
# Predicted Temperature for Row 567: 48.73°C
# Predicted Temperature for Row 568: 50.60°C
# Predicted Temperature for Row 569: 51.88°C
# Predicted Temperature for Row 570: 48.87°C
# Predicted Temperature for Row 571: 49.70°C
# Predicted Temperature for Row 572: 52.67°C
# Predicted Temperature for Row 573: 48.52°C
# Predicted Temperature for Row 574: 49.10°C
# Predicted Temperature for Row 575: 51.89°C
# Predicted Temperature for Row 576: 54.10°C
# Predicted Temperature for Row 577: 49.23°C
# Predicted Temperature for Row 578: 52.34°C
# Predicted Temperature for Row 579: 49.46°C
# Predicted Temperature for Row 580: 48.69°C
# Predicted Temperature for Row 581: 50.25°C
# Predicted Temperature for Row 582: 52.64°C
# Predicted Temperature for Row 583: 49.71°C
# Predicted Temperature for Row 584: 48.86°C
# Predicted Temperature for Row 585: 49.48°C
# Predicted Temperature for Row 586: 49.68°C
# Predicted Temperature for Row 587: 46.84°C
# Predicted Temperature for Row 588: 48.28°C
# Predicted Temperature for Row 589: 47.54°C
# Predicted Temperature for Row 590: 47.28°C
# Predicted Temperature for Row 591: 47.28°C
# Predicted Temperature for Row 592: 49.56°C
# Predicted Temperature for Row 593: 49.42°C
# Predicted Temperature for Row 594: 50.29°C
# Predicted Temperature for Row 595: 51.12°C
# Predicted Temperature for Row 596: 49.71°C
# Predicted Temperature for Row 597: 51.35°C
# Predicted Temperature for Row 598: 49.52°C
# Predicted Temperature for Row 599: 49.49°C
# Predicted Temperature for Row 600: 46.38°C
# Predicted Temperature for Row 601: 48.89°C
# Predicted Temperature for Row 602: 49.05°C
# Predicted Temperature for Row 603: 48.92°C
# Predicted Temperature for Row 604: 48.02°C
# Predicted Temperature for Row 605: 48.69°C
# Predicted Temperature for Row 606: 49.56°C
# Predicted Temperature for Row 607: 49.38°C
# Predicted Temperature for Row 608: 47.92°C
# Predicted Temperature for Row 609: 50.06°C
# Predicted Temperature for Row 610: 49.85°C
# Predicted Temperature for Row 611: 46.66°C
# Predicted Temperature for Row 612: 50.11°C
# Predicted Temperature for Row 613: 50.35°C
# Predicted Temperature for Row 614: 48.16°C
# Predicted Temperature for Row 615: 52.55°C
# Predicted Temperature for Row 616: 51.00°C
# Predicted Temperature for Row 617: 46.28°C
# Predicted Temperature for Row 618: 48.15°C
# Predicted Temperature for Row 619: 51.38°C
# Predicted Temperature for Row 620: 50.33°C
# Predicted Temperature for Row 621: 48.43°C
# Predicted Temperature for Row 622: 49.58°C
# Predicted Temperature for Row 623: 48.86°C
# Predicted Temperature for Row 624: 48.52°C
# Predicted Temperature for Row 625: 51.53°C
# Predicted Temperature for Row 626: 48.84°C
# Predicted Temperature for Row 627: 49.64°C
# Predicted Temperature for Row 628: 50.88°C
# Predicted Temperature for Row 629: 48.69°C
# Predicted Temperature for Row 630: 48.84°C
# Predicted Temperature for Row 631: 50.43°C
# Predicted Temperature for Row 632: 53.15°C
# Predicted Temperature for Row 633: 48.89°C
# Predicted Temperature for Row 634: 48.76°C
# Predicted Temperature for Row 635: 46.07°C
# Predicted Temperature for Row 636: 50.56°C
# Predicted Temperature for Row 637: 49.73°C
# Predicted Temperature for Row 638: 49.29°C
# Predicted Temperature for Row 639: 47.39°C
# Predicted Temperature for Row 640: 47.98°C
# Predicted Temperature for Row 641: 46.95°C
# Predicted Temperature for Row 642: 47.62°C
# Predicted Temperature for Row 643: 48.50°C
# Predicted Temperature for Row 644: 48.84°C
# Predicted Temperature for Row 645: 49.06°C
# Predicted Temperature for Row 646: 51.26°C
# Predicted Temperature for Row 647: 51.62°C
# Predicted Temperature for Row 648: 50.15°C
# Predicted Temperature for Row 649: 50.79°C
# Predicted Temperature for Row 650: 48.84°C
# Predicted Temperature for Row 651: 49.13°C
# Predicted Temperature for Row 652: 50.72°C
# Predicted Temperature for Row 653: 50.67°C
# Predicted Temperature for Row 654: 51.02°C
# Predicted Temperature for Row 655: 50.68°C
# Predicted Temperature for Row 656: 46.17°C
# Predicted Temperature for Row 657: 48.76°C
# Predicted Temperature for Row 658: 49.86°C
# Predicted Temperature for Row 659: 50.79°C
# Predicted Temperature for Row 660: 50.02°C
# Predicted Temperature for Row 661: 48.98°C
# Predicted Temperature for Row 662: 53.28°C
# Predicted Temperature for Row 663: 48.23°C
# Predicted Temperature for Row 664: 48.11°C
# Predicted Temperature for Row 665: 46.64°C
# Predicted Temperature for Row 666: 46.94°C
# Predicted Temperature for Row 667: 49.18°C
# Predicted Temperature for Row 668: 46.51°C
# Predicted Temperature for Row 669: 49.03°C
# Predicted Temperature for Row 670: 47.75°C
# Predicted Temperature for Row 671: 48.50°C
# Predicted Temperature for Row 672: 50.78°C
# Predicted Temperature for Row 673: 46.93°C
# Predicted Temperature for Row 674: 48.28°C
# Predicted Temperature for Row 675: 48.87°C
# Predicted Temperature for Row 676: 53.29°C
# Predicted Temperature for Row 677: 48.88°C
# Predicted Temperature for Row 678: 49.23°C
# Predicted Temperature for Row 679: 52.65°C
# Predicted Temperature for Row 680: 51.73°C
# Predicted Temperature for Row 681: 51.71°C
# Predicted Temperature for Row 682: 47.01°C
# Predicted Temperature for Row 683: 47.58°C
# Predicted Temperature for Row 684: 49.73°C
# Predicted Temperature for Row 685: 53.11°C
# Predicted Temperature for Row 686: 48.56°C
# Predicted Temperature for Row 687: 48.45°C
# Predicted Temperature for Row 688: 48.80°C
# Predicted Temperature for Row 689: 51.06°C
# Predicted Temperature for Row 690: 46.54°C
# Predicted Temperature for Row 691: 49.66°C
# Predicted Temperature for Row 692: 49.69°C
# Predicted Temperature for Row 693: 49.69°C
# Predicted Temperature for Row 694: 49.52°C
# Predicted Temperature for Row 695: 48.25°C
# Predicted Temperature for Row 696: 51.75°C
# Predicted Temperature for Row 697: 49.40°C
# Predicted Temperature for Row 698: 51.22°C
# Predicted Temperature for Row 699: 46.82°C
# Predicted Temperature for Row 700: 49.90°C
# Predicted Temperature for Row 701: 48.91°C
# Predicted Temperature for Row 702: 47.69°C
# Predicted Temperature for Row 703: 49.25°C
# Predicted Temperature for Row 704: 47.83°C
# Predicted Temperature for Row 705: 47.54°C
# Predicted Temperature for Row 706: 53.07°C
# Predicted Temperature for Row 707: 48.34°C
# Predicted Temperature for Row 708: 52.43°C
# Predicted Temperature for Row 709: 47.51°C
# Predicted Temperature for Row 710: 49.81°C
# Predicted Temperature for Row 711: 52.73°C
# Predicted Temperature for Row 712: 51.48°C
# Predicted Temperature for Row 713: 48.90°C
# Predicted Temperature for Row 714: 49.57°C
# Predicted Temperature for Row 715: 49.61°C
# Predicted Temperature for Row 716: 50.74°C
# Predicted Temperature for Row 717: 53.44°C
# Predicted Temperature for Row 718: 52.90°C
# Predicted Temperature for Row 719: 46.74°C
# Predicted Temperature for Row 720: 51.40°C
# Predicted Temperature for Row 721: 54.07°C
# Predicted Temperature for Row 722: 48.94°C
# Predicted Temperature for Row 723: 47.85°C
# Predicted Temperature for Row 724: 52.58°C
# Predicted Temperature for Row 725: 49.76°C
# Predicted Temperature for Row 726: 52.09°C
# Predicted Temperature for Row 727: 46.82°C
# Predicted Temperature for Row 728: 49.31°C
# Predicted Temperature for Row 729: 46.64°C
# Predicted Temperature for Row 730: 48.00°C
# Predicted Temperature for Row 731: 48.55°C
# Predicted Temperature for Row 732: 50.67°C
# Predicted Temperature for Row 733: 50.26°C
# Predicted Temperature for Row 734: 50.48°C
# Predicted Temperature for Row 735: 50.29°C
# Predicted Temperature for Row 736: 51.56°C
# Predicted Temperature for Row 737: 49.45°C
# Predicted Temperature for Row 738: 52.30°C
# Predicted Temperature for Row 739: 49.73°C
# Predicted Temperature for Row 740: 49.24°C
# Predicted Temperature for Row 741: 48.52°C
# Predicted Temperature for Row 742: 48.05°C
# Predicted Temperature for Row 743: 50.08°C
# Predicted Temperature for Row 744: 50.79°C
# Predicted Temperature for Row 745: 48.24°C
# Predicted Temperature for Row 746: 52.90°C
# Predicted Temperature for Row 747: 50.59°C
# Predicted Temperature for Row 748: 50.61°C
# Predicted Temperature for Row 749: 52.17°C
# Predicted Temperature for Row 750: 51.02°C
# Predicted Temperature for Row 751: 47.82°C
# Predicted Temperature for Row 752: 52.49°C
# Predicted Temperature for Row 753: 51.98°C
# Predicted Temperature for Row 754: 49.74°C
# Predicted Temperature for Row 755: 46.62°C
# Predicted Temperature for Row 756: 50.35°C
# Predicted Temperature for Row 757: 49.04°C
# Predicted Temperature for Row 758: 50.47°C
# Predicted Temperature for Row 759: 53.67°C
# Predicted Temperature for Row 760: 50.58°C
# Predicted Temperature for Row 761: 47.41°C
# Predicted Temperature for Row 762: 47.51°C
# Predicted Temperature for Row 763: 49.83°C
# Predicted Temperature for Row 764: 51.45°C
# Predicted Temperature for Row 765: 48.58°C
# Predicted Temperature for Row 766: 51.13°C
# Predicted Temperature for Row 767: 50.88°C
# Predicted Temperature for Row 768: 51.99°C
# Predicted Temperature for Row 769: 49.28°C
# Predicted Temperature for Row 770: 52.44°C
# Predicted Temperature for Row 771: 47.90°C
# Predicted Temperature for Row 772: 50.42°C
# Predicted Temperature for Row 773: 46.89°C
# Predicted Temperature for Row 774: 48.13°C
# Predicted Temperature for Row 775: 50.90°C
# Predicted Temperature for Row 776: 48.42°C
# Predicted Temperature for Row 777: 47.69°C
# Predicted Temperature for Row 778: 51.04°C
# Predicted Temperature for Row 779: 51.76°C
# Predicted Temperature for Row 780: 49.17°C
# Predicted Temperature for Row 781: 51.97°C
# Predicted Temperature for Row 782: 49.36°C
# Predicted Temperature for Row 783: 48.36°C
# Predicted Temperature for Row 784: 48.63°C
# Predicted Temperature for Row 785: 47.78°C
# Predicted Temperature for Row 786: 50.51°C
# Predicted Temperature for Row 787: 50.28°C
# Predicted Temperature for Row 788: 48.84°C
# Predicted Temperature for Row 789: 51.05°C
# Predicted Temperature for Row 790: 51.64°C
# Predicted Temperature for Row 791: 49.05°C
# Predicted Temperature for Row 792: 49.93°C
# Predicted Temperature for Row 793: 50.06°C
# Predicted Temperature for Row 794: 49.75°C
# Predicted Temperature for Row 795: 48.23°C
# Predicted Temperature for Row 796: 53.12°C
# Predicted Temperature for Row 797: 51.18°C
# Predicted Temperature for Row 798: 51.62°C
# Predicted Temperature for Row 799: 52.66°C
# Predicted Temperature for Row 800: 53.41°C
# Predicted Temperature for Row 801: 50.23°C
# Predicted Temperature for Row 802: 47.20°C
# Predicted Temperature for Row 803: 50.37°C
# Predicted Temperature for Row 804: 50.09°C
# Predicted Temperature for Row 805: 49.99°C
# Predicted Temperature for Row 806: 50.00°C
# Predicted Temperature for Row 807: 52.55°C
# Predicted Temperature for Row 808: 53.06°C
# Predicted Temperature for Row 809: 50.37°C
# Predicted Temperature for Row 810: 48.70°C
# Predicted Temperature for Row 811: 51.87°C
# Predicted Temperature for Row 812: 51.50°C
# Predicted Temperature for Row 813: 48.56°C
# Predicted Temperature for Row 814: 53.27°C
# Predicted Temperature for Row 815: 53.61°C
# Predicted Temperature for Row 816: 49.03°C
# Predicted Temperature for Row 817: 51.17°C
# Predicted Temperature for Row 818: 48.09°C
# Predicted Temperature for Row 819: 47.19°C
# Predicted Temperature for Row 820: 49.42°C
# Predicted Temperature for Row 821: 52.97°C
# Predicted Temperature for Row 822: 48.46°C
# Predicted Temperature for Row 823: 48.69°C
# Predicted Temperature for Row 824: 48.17°C
# Predicted Temperature for Row 825: 49.39°C
# Predicted Temperature for Row 826: 52.91°C
# Predicted Temperature for Row 827: 50.50°C
# Predicted Temperature for Row 828: 47.24°C
# Predicted Temperature for Row 829: 50.12°C
# Predicted Temperature for Row 830: 49.61°C
# Predicted Temperature for Row 831: 47.00°C
# Predicted Temperature for Row 832: 49.31°C
# Predicted Temperature for Row 833: 47.73°C
# Predicted Temperature for Row 834: 47.30°C
# Predicted Temperature for Row 835: 49.01°C
# Predicted Temperature for Row 836: 49.28°C
# Predicted Temperature for Row 837: 52.29°C
# Predicted Temperature for Row 838: 48.78°C
# Predicted Temperature for Row 839: 48.97°C
# Predicted Temperature for Row 840: 51.27°C
# Predicted Temperature for Row 841: 47.96°C
# Predicted Temperature for Row 842: 51.19°C
# Predicted Temperature for Row 843: 48.48°C
# Predicted Temperature for Row 844: 53.02°C
# Predicted Temperature for Row 845: 46.33°C
# Predicted Temperature for Row 846: 50.16°C
# Predicted Temperature for Row 847: 48.19°C
# Predicted Temperature for Row 848: 53.43°C
# Predicted Temperature for Row 849: 48.94°C
# Predicted Temperature for Row 850: 49.53°C
# Predicted Temperature for Row 851: 48.40°C
# Predicted Temperature for Row 852: 49.76°C
# Predicted Temperature for Row 853: 47.24°C
# Predicted Temperature for Row 854: 50.92°C
# Predicted Temperature for Row 855: 46.94°C
# Predicted Temperature for Row 856: 48.63°C
# Predicted Temperature for Row 857: 46.46°C
# Predicted Temperature for Row 858: 49.48°C
# Predicted Temperature for Row 859: 48.57°C
# Predicted Temperature for Row 860: 47.07°C
# Predicted Temperature for Row 861: 50.69°C
# Predicted Temperature for Row 862: 49.13°C
# Predicted Temperature for Row 863: 51.19°C
# Predicted Temperature for Row 864: 49.53°C
# Predicted Temperature for Row 865: 47.34°C
# Predicted Temperature for Row 866: 49.14°C
# Predicted Temperature for Row 867: 49.54°C
# Predicted Temperature for Row 868: 49.14°C
# Predicted Temperature for Row 869: 52.71°C
# Predicted Temperature for Row 870: 51.60°C
# Predicted Temperature for Row 871: 48.60°C
# Predicted Temperature for Row 872: 49.47°C
# Predicted Temperature for Row 873: 51.08°C
# Predicted Temperature for Row 874: 48.38°C
# Predicted Temperature for Row 875: 46.12°C
# Predicted Temperature for Row 876: 48.07°C
# Predicted Temperature for Row 877: 50.91°C
# Predicted Temperature for Row 878: 50.16°C
# Predicted Temperature for Row 879: 48.24°C
# Predicted Temperature for Row 880: 47.72°C
# Predicted Temperature for Row 881: 47.95°C
# Predicted Temperature for Row 882: 50.03°C
# Predicted Temperature for Row 883: 47.09°C
# Predicted Temperature for Row 884: 46.19°C
# Predicted Temperature for Row 885: 51.56°C
# Predicted Temperature for Row 886: 47.84°C
# Predicted Temperature for Row 887: 51.36°C
# Predicted Temperature for Row 888: 49.34°C
# Predicted Temperature for Row 889: 47.38°C
# Predicted Temperature for Row 890: 47.34°C
# Predicted Temperature for Row 891: 51.90°C
# Predicted Temperature for Row 892: 52.54°C
# Predicted Temperature for Row 893: 51.22°C
# Predicted Temperature for Row 894: 50.38°C
# Predicted Temperature for Row 895: 50.25°C
# Predicted Temperature for Row 896: 47.68°C
# Predicted Temperature for Row 897: 48.20°C
# Predicted Temperature for Row 898: 52.35°C
# Predicted Temperature for Row 899: 48.02°C
# Predicted Temperature for Row 900: 46.85°C
# Predicted Temperature for Row 901: 47.96°C
# Predicted Temperature for Row 902: 48.88°C
# Predicted Temperature for Row 903: 47.19°C
# Predicted Temperature for Row 904: 51.79°C
# Predicted Temperature for Row 905: 48.72°C
# Predicted Temperature for Row 906: 52.55°C
# Predicted Temperature for Row 907: 51.08°C
# Predicted Temperature for Row 908: 49.22°C
# Predicted Temperature for Row 909: 49.18°C
# Predicted Temperature for Row 910: 50.23°C
# Predicted Temperature for Row 911: 50.40°C
# Predicted Temperature for Row 912: 46.57°C
# Predicted Temperature for Row 913: 48.99°C
# Predicted Temperature for Row 914: 48.96°C
# Predicted Temperature for Row 915: 49.65°C
# Predicted Temperature for Row 916: 49.15°C
# Predicted Temperature for Row 917: 47.92°C
# Predicted Temperature for Row 918: 52.97°C
# Predicted Temperature for Row 919: 51.60°C
# Predicted Temperature for Row 920: 48.32°C
# Predicted Temperature for Row 921: 50.71°C
# Predicted Temperature for Row 922: 51.44°C
# Predicted Temperature for Row 923: 51.82°C
# Predicted Temperature for Row 924: 51.75°C
# Predicted Temperature for Row 925: 48.29°C
# Predicted Temperature for Row 926: 48.08°C
# Predicted Temperature for Row 927: 48.61°C
# Predicted Temperature for Row 928: 50.25°C
# Predicted Temperature for Row 929: 50.40°C
# Predicted Temperature for Row 930: 49.64°C
# Predicted Temperature for Row 931: 47.70°C
# Predicted Temperature for Row 932: 52.06°C
# Predicted Temperature for Row 933: 51.91°C
# Predicted Temperature for Row 934: 49.79°C
# Predicted Temperature for Row 935: 47.71°C
# Predicted Temperature for Row 936: 47.62°C
# Predicted Temperature for Row 937: 48.14°C
# Predicted Temperature for Row 938: 51.65°C
# Predicted Temperature for Row 939: 47.72°C
# Predicted Temperature for Row 940: 51.21°C
# Predicted Temperature for Row 941: 49.85°C
# Predicted Temperature for Row 942: 50.22°C
# Predicted Temperature for Row 943: 49.30°C
# Predicted Temperature for Row 944: 51.70°C
# Predicted Temperature for Row 945: 47.18°C
# Predicted Temperature for Row 946: 46.03°C
# Predicted Temperature for Row 947: 48.35°C
# Predicted Temperature for Row 948: 53.21°C
# Predicted Temperature for Row 949: 52.59°C
# Predicted Temperature for Row 950: 51.02°C
# Predicted Temperature for Row 951: 51.83°C
# Predicted Temperature for Row 952: 51.20°C
# Predicted Temperature for Row 953: 47.67°C
# Predicted Temperature for Row 954: 51.68°C
# Predicted Temperature for Row 955: 48.22°C
# Predicted Temperature for Row 956: 48.08°C
# Predicted Temperature for Row 957: 49.29°C
# Predicted Temperature for Row 958: 47.84°C
# Predicted Temperature for Row 959: 46.80°C
# Predicted Temperature for Row 960: 50.68°C
# Predicted Temperature for Row 961: 48.95°C
# Predicted Temperature for Row 962: 50.74°C
# Predicted Temperature for Row 963: 46.52°C
# Predicted Temperature for Row 964: 49.69°C
# Predicted Temperature for Row 965: 48.24°C
# Predicted Temperature for Row 966: 48.88°C
# Predicted Temperature for Row 967: 52.44°C
# Predicted Temperature for Row 968: 48.85°C
# Predicted Temperature for Row 969: 50.85°C
# Predicted Temperature for Row 970: 51.28°C
# Predicted Temperature for Row 971: 51.19°C
# Predicted Temperature for Row 972: 51.05°C
# Predicted Temperature for Row 973: 52.32°C
# Predicted Temperature for Row 974: 48.45°C
# Predicted Temperature for Row 975: 47.95°C
# Predicted Temperature for Row 976: 46.99°C
# Predicted Temperature for Row 977: 51.45°C
# Predicted Temperature for Row 978: 47.69°C
# Predicted Temperature for Row 979: 48.60°C
# Predicted Temperature for Row 980: 49.96°C
# Predicted Temperature for Row 981: 49.69°C
# Predicted Temperature for Row 982: 50.10°C
# Predicted Temperature for Row 983: 47.88°C
# Predicted Temperature for Row 984: 47.63°C
# Predicted Temperature for Row 985: 51.78°C
# Predicted Temperature for Row 986: 50.06°C
# Predicted Temperature for Row 987: 49.16°C
# Predicted Temperature for Row 988: 49.71°C
# Predicted Temperature for Row 989: 48.87°C
# Predicted Temperature for Row 990: 50.90°C
# Predicted Temperature for Row 991: 50.05°C
# Predicted Temperature for Row 992: 52.38°C
# Predicted Temperature for Row 993: 48.47°C
# Predicted Temperature for Row 994: 51.28°C
# Predicted Temperature for Row 995: 48.12°C
# Predicted Temperature for Row 996: 47.46°C
# Predicted Temperature for Row 997: 50.45°C
# Predicted Temperature for Row 998: 49.31°C
# Predicted Temperature for Row 999: 53.64°C
# Predicted Temperature for Row 1000: 50.38°C

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
np.random.seed(42)
num_samples = 1000
data = np.random.uniform(0, 1, (num_samples, 4))
data[:, 0] = data[:, 0] * 100
data[:, 1] = data[:, 1] * 30
data[:, 2] = data[:, 2] * 50 + 990
data[:, 3] = data[:, 3] * 100
temperature = 25 + 0.1 * data[:, 0] - 0.05 * data[:, 1] + 0.02 * data[:, 2] - 0.01 * data[:, 3]
temperature += np.random.normal(0, 5, num_samples)
X = data
y = temperature
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
num_inputs = int(input("Enter the number of inputs: "))
for i in range(num_inputs):
    print(f"Enter data for input {i+1}:")
    humidity = float(input("Humidity (%): "))
    wind_speed = float(input("Wind Speed (km/h): "))
    pressure = float(input("Pressure (hPa): "))
    precipitation = float(input("Precipitation (mm): "))
    user_input = np.array([[humidity, wind_speed, pressure, precipitation]])
    user_input_poly = poly.transform(user_input)
    predicted_temp = model.predict(user_input_poly)
    print(f"Predicted Temperature for Input {i+1}: {predicted_temp[0]:.2f}°C")
# Out:
# Enter the number of inputs: 2
# Enter data for input 1:
# Humidity (%): 6
# Wind Speed (km/h): 6
# Pressure (hPa): 1300
# Precipitation (mm): 20
# Predicted Temperature for Input 1: -34.24°C
# Enter data for input 2:
# Humidity (%): 34
# Wind Speed (km/h): 10
# Pressure (hPa): 1400
# Precipitation (mm): 30
# Predicted Temperature for Input 2: -89.56°C
